# %% [markdown]
# # Introducción a los bosques de corte aleatorio de SageMaker
#
# [LINK](https://github.com/aws/amazon-sagemaker-examples/blob/main/introduction_to_amazon_algorithms/random_cut_forest/random_cut_forest.ipynb)

# %%
import boto3
import botocore
import sagemaker
import sys

# %%
bucket = (
    sagemaker.Session().default_bucket()
)  # Feel free to change to another bucket you have access to
prefix = "sagemaker/rcf-benchmarks"
execution_role = 'AmazonSageMaker-ExecutionRole-20220328T145246'
region = boto3.Session().region_name
print(f"Bucket: {bucket}")
# Out:
# Bucket: sagemaker-us-east-1-195566616656

# %%
# S3 bucket where the original data is downloaded and stored.
downloaded_data_bucket = f"sagemaker-sample-files"
downloaded_data_prefix = "datasets/tabular/anomaly_benchmark_taxi"

# %%
def check_bucket_permission(bucket):
    # check if the bucket exists
    permission = False
    try:
        boto3.Session().client("s3").head_bucket(Bucket=bucket)
    except botocore.exceptions.ParamValidationError as e:
        print(
            "Hey! You either forgot to specify your S3 bucket"
            " or you gave your bucket an invalid name!"
        )
    except botocore.exceptions.ClientError as e:
        if e.response["Error"]["Code"] == "403":
            print(f"Hey! You don't have permission to access the bucket, {bucket}.")
        elif e.response["Error"]["Code"] == "404":
            print(f"Hey! Your bucket, {bucket}, doesn't exist!")
        else:
            raise
    else:
        permission = True
    return permission

# %%
if check_bucket_permission(bucket):
    print(f"Training input/output will be stored in: s3://{bucket}/{prefix}")
if check_bucket_permission(downloaded_data_bucket):
    print(
        f"Downloaded training data will be read from s3://{downloaded_data_bucket}/{downloaded_data_prefix}"
    )
# Out:
# Training input/output will be stored in: s3://sagemaker-us-east-1-195566616656/sagemaker/rcf-benchmarks
# Downloaded training data will be read from s3://sagemaker-sample-files/datasets/tabular/anomaly_benchmark_taxi

# %%
# %%time

import pandas as pd

data_filename = "NAB_nyc_taxi.csv"
s3 = boto3.client("s3")
s3.download_file(downloaded_data_bucket, f"{downloaded_data_prefix}/{data_filename}", data_filename)
taxi_data = pd.read_csv(data_filename, delimiter=",")
# Out:
# CPU times: user 130 ms, sys: 4.63 ms, total: 134 ms
# Wall time: 321 ms

# %%
taxi_data.head()
# Out:
#              timestamp  value
# 0  2014-07-01 00:00:00  10844
# 1  2014-07-01 00:30:00   8127
# 2  2014-07-01 01:00:00   6210
# 3  2014-07-01 01:30:00   4656
# 4  2014-07-01 02:00:00   3820

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams["figure.dpi"] = 100

taxi_data.plot();

# %%
taxi_data[5580:6595].plot();

# %%
taxi_data[5952:5965]
# Out:
#                 timestamp  value
# 5952  2014-11-02 00:00:00  25110
# 5953  2014-11-02 00:30:00  23109
# 5954  2014-11-02 01:00:00  39197
# 5955  2014-11-02 01:30:00  35212
# 5956  2014-11-02 02:00:00  13259
# 5957  2014-11-02 02:30:00  12250
# 5958  2014-11-02 03:00:00  10013
# 5959  2014-11-02 03:30:00   7898
# 5960  2014-11-02 04:00:00   6375
# 5961  2014-11-02 04:30:00   4532
# 5962  2014-11-02 05:00:00   5116
# 5963  2014-11-02 05:30:00   5232
# 5964  2014-11-02 06:00:00   4542

# %%
from sagemaker import RandomCutForest

session = sagemaker.Session()

# specify general training job information
rcf = RandomCutForest(
    role=execution_role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    data_location=f"s3://{bucket}/{prefix}/",
    output_path=f"s3://{bucket}/{prefix}/output",
    num_samples_per_tree=512,
    num_trees=50,
)

# automatically upload the training data to S3 and run the training job
rcf.fit(rcf.record_set(taxi_data.value.to_numpy().reshape(-1, 1)))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-04-27 00:58:05 Starting - Starting the training job...
# 2022-04-27 00:58:32 Starting - Preparing the instances for trainingProfilerReport-1651021085: InProgress
# .........
# 2022-04-27 01:00:02 Downloading - Downloading input data......
# 2022-04-27 01:00:59 Training - Downloading the training image...
# 2022-04-27 01:01:39 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/27/2022 01:01:45 INFO 139815788971840 integration.py:636] worker started
# [04/27/2022 01:01:45 INFO 139815788971840] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [04/27/2022 01:01:45 INFO 139815788971840] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '1', 'mini_batch_size': '1000', 'num_samples_per_tree': '512', 'num_trees': '50'}
# [04/27/2022 01:01:45 INFO 139815788971840] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '50', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '1'}
# [04/27/2022 01:01:45 WARNING 139815788971840] Loggers have already been setup.
# [04/27/2022 01:01:45 INFO 139815788971840] Launching parameter server for role scheduler
# [04/27/2022 01:01:45 INFO 139815788971840] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-146-193.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-00-58-05-414', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-00-58-05-414', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-c53e76911e8e6623f8a34b80b60e51fb44acc9956e170725f24cd70d30e6060a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [04/27/2022 01:01:45 INFO 139815788971840] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-146-193.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-00-58-05-414', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-00-58-05-414', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-c53e76911e8e6623f8a34b80b60e51fb44acc9956e170725f24cd70d30e6060a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.146.193', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [04/27/2022 01:01:45 INFO 139815788971840] Launching parameter server for role server
# [04/27/2022 01:01:45 INFO 139815788971840] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-146-193.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-00-58-05-414', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-00-58-05-414', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-c53e76911e8e6623f8a34b80b60e51fb44acc9956e170725f24cd70d30e6060a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [04/27/2022 01:01:45 INFO 139815788971840] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-146-193.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-00-58-05-414', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-00-58-05-414', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-c53e76911e8e6623f8a34b80b60e51fb44acc9956e170725f24cd70d30e6060a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.146.193', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [04/27/2022 01:01:45 INFO 139815788971840] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-146-193.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-00-58-05-414', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-00-58-05-414', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-c53e76911e8e6623f8a34b80b60e51fb44acc9956e170725f24cd70d30e6060a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.146.193', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 34 is a shell:scheduler.
# Process 43 is a shell:server.
# Process 1 is a worker.
# [04/27/2022 01:01:45 INFO 139815788971840] Using default worker.
# [04/27/2022 01:01:45 INFO 139815788971840] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/27/2022 01:01:45 INFO 139815788971840] Checkpoint loading and saving are disabled.
# [04/27/2022 01:01:45 INFO 139815788971840] Verifying hyperparamemters...
# [04/27/2022 01:01:45 INFO 139815788971840] Hyperparameters are correct.
# [04/27/2022 01:01:45 INFO 139815788971840] Validating that feature_dim agrees with dimensions in training data...
# [04/27/2022 01:01:45 INFO 139815788971840] feature_dim is correct.
# [04/27/2022 01:01:45 INFO 139815788971840] Validating memory limits...
# [04/27/2022 01:01:45 INFO 139815788971840] Available memory in bytes: 15305560064
# [04/27/2022 01:01:45 INFO 139815788971840] Estimated sample size in bytes: 204800
# [04/27/2022 01:01:45 INFO 139815788971840] Estimated memory needed to build the forest in bytes: 1024000
# [04/27/2022 01:01:45 INFO 139815788971840] Memory limits validated.
# [04/27/2022 01:01:45 INFO 139815788971840] Starting cluster sharing facilities...
# [04/27/2022 01:01:45 INFO 139814003275520] concurrency model: async
# [04/27/2022 01:01:45 INFO 139814003275520] masquerade (NAT) address: None
# [04/27/2022 01:01:45 INFO 139814003275520] passive ports: None
# [04/27/2022 01:01:45 INFO 139814003275520] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [04/27/2022 01:01:45 INFO 139815788971840] Create Store: dist_async
# [04/27/2022 01:01:46 INFO 139815788971840] Cluster sharing facilities started.
# [04/27/2022 01:01:46 INFO 139815788971840] Verifying all workers are accessible...
# [04/27/2022 01:01:46 INFO 139815788971840] All workers accessible.
# [04/27/2022 01:01:46 INFO 139815788971840] Initializing Sampler...
# [04/27/2022 01:01:46 INFO 139815788971840] Sampler correctly initialized.
# #metrics {"StartTime": 1651021305.1501796, "EndTime": 1651021306.7828236, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1615.0331497192383, "count": 1, "min": 1615.0331497192383, "max": 1615.0331497192383}}}
# #metrics {"StartTime": 1651021306.7830837, "EndTime": 1651021306.7831426, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-04-27 01:01:46.783] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1632, "num_examples": 1, "num_bytes": 28000}
# [04/27/2022 01:01:46 INFO 139815788971840] Sampling training data...
# [2022-04-27 01:01:46.826] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 42, "num_examples": 11, "num_bytes": 288960}
# [04/27/2022 01:01:46 INFO 139815788971840] Sampling training data completed.
# #metrics {"StartTime": 1651021306.783008, "EndTime": 1651021306.8335288, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 49.86977577209473, "count": 1, "min": 49.86977577209473, "max": 49.86977577209473}}}
# [04/27/2022 01:01:46 INFO 139815788971840] Early stop condition met. Stopping training.
# [04/27/2022 01:01:46 INFO 139815788971840] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1651021306.78361, "EndTime": 1651021306.833957, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10320.0, "count": 1, "min": 10320, "max": 10320}, "Total Batches Seen": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Max Records Seen Between Resets": {"sum": 10320.0, "count": 1, "min": 10320, "max": 10320}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 10320.0, "count": 1, "min": 10320, "max": 10320}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
# [04/27/2022 01:01:46 INFO 139815788971840] #throughput_metric: host=algo-1, train throughput=204429.1610819082 records/second
# [04/27/2022 01:01:46 INFO 139815788971840] Master node: building Random Cut Forest...
# [04/27/2022 01:01:46 INFO 139815788971840] Gathering samples...
# [04/27/2022 01:01:46 INFO 139815788971840] 10320 samples gathered
# [04/27/2022 01:01:46 INFO 139815788971840] Building Random Cut Forest...
# [04/27/2022 01:01:46 INFO 139815788971840] Random Cut Forest built:
# ForestInfo{num_trees: 50, num_samples_in_forest: 10300, num_samples_per_tree: 206, sample_dim: 1, shingle_size: 1, trees_num_nodes: [405, 403, 409, 409, 411, 409, 407, 409, 407, 411, 409, 411, 411, 407, 405, 409, 407, 409, 409, 409, 411, 411, 401, 409, 409, 411, 407, 411, 411, 401, 411, 405, 411, 411, 409, 409, 411, 405, 409, 407, 409, 411, 411, 407, 409, 411, 407, 407, 411, 409, ], trees_depth: [17, 17, 16, 15, 20, 21, 17, 20, 16, 21, 16, 16, 19, 19, 16, 15, 19, 17, 20, 20, 17, 15, 17, 17, 19, 18, 17, 17, 18, 20, 17, 16, 16, 18, 16, 18, 18, 14, 20, 18, 16, 16, 23, 17, 17, 16, 17, 19, 18, 19, ], max_num_nodes: 411, min_num_nodes: 401, avg_num_nodes: 408, max_tree_depth: 23, min_tree_depth: 14, avg_tree_depth: 17, mem_size: 2124960}
# #metrics {"StartTime": 1651021306.8336766, "EndTime": 1651021306.8502192, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 8.454561233520508, "count": 1, "min": 8.454561233520508, "max": 8.454561233520508}, "model.bytes": {"sum": 2124960.0, "count": 1, "min": 2124960, "max": 2124960}, "finalize.time": {"sum": 15.898466110229492, "count": 1, "min": 15.898466110229492, "max": 15.898466110229492}}}
# [04/27/2022 01:01:46 INFO 139815788971840] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1651021306.850346, "EndTime": 1651021306.8835917, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 33.16640853881836, "count": 1, "min": 33.16640853881836, "max": 33.16640853881836}}}
# [04/27/2022 01:01:46 INFO 139815788971840] Test data is not provided.
# #metrics {"StartTime": 1651021306.883719, "EndTime": 1651021306.8838632, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 45.95327377319336, "count": 1, "min": 45.95327377319336, "max": 45.95327377319336}, "totaltime": {"sum": 1802.5751113891602, "count": 1, "min": 1802.5751113891602, "max": 1802.5751113891602}}}
# [04/27/2022 01:01:46 INFO 139815788971840 integration.py:636] worker closed
#
# 2022-04-27 01:02:04 Uploading - Uploading generated training model
# 2022-04-27 01:02:04 Completed - Training job completed
# Training seconds: 122
# Billable seconds: 122

# %%
print(f"Training job name: {rcf.latest_training_job.job_name}")
# Out:
# Training job name: randomcutforest-2022-04-27-00-58-05-414

# %%
rcf_inference = rcf.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ------!

# %%
print(f"Endpoint name: {rcf_inference.endpoint}")
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Endpoint name: randomcutforest-2022-04-27-01-03-00-916

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

rcf_inference.serializer = CSVSerializer()
rcf_inference.deserializer = JSONDeserializer()

# %%
taxi_data_numpy = taxi_data.value.to_numpy().reshape(-1, 1)
print(taxi_data_numpy[:6])
results = rcf_inference.predict(
    taxi_data_numpy[:6], initial_args={"ContentType": "text/csv", "Accept": "application/json"}
)
# Out:
# [[10844]
#  [ 8127]
#  [ 6210]
#  [ 4656]
#  [ 3820]
#  [ 2873]]

# %%
results = rcf_inference.predict(taxi_data_numpy)
scores = [datum["score"] for datum in results["scores"]]

# add scores to taxi data frame and print first few values
taxi_data["score"] = pd.Series(scores, index=taxi_data.index)
taxi_data.head()
# Out:
#              timestamp  value     score
# 0  2014-07-01 00:00:00  10844  1.039514
# 1  2014-07-01 00:30:00   8127  1.029384
# 2  2014-07-01 01:00:00   6210  0.988584
# 3  2014-07-01 01:30:00   4656  0.911292
# 4  2014-07-01 02:00:00   3820  0.879395

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

#
# *Try this out* - change `start` and `end` to zoom in on the
# anomaly found earlier in this notebook
#
start, end = 0, len(taxi_data)
# start, end = 5500, 6500
taxi_data_subset = taxi_data[start:end]

ax1.plot(taxi_data_subset["value"], color="C0", alpha=0.8)
ax2.plot(taxi_data_subset["score"], color="C1")

ax1.grid(which="major", axis="both")

ax1.set_ylabel("Taxi Ridership", color="C0")
ax2.set_ylabel("Anomaly Score", color="C1")

ax1.tick_params("y", colors="C0")
ax2.tick_params("y", colors="C1")

ax1.set_ylim(0, 40000)
ax2.set_ylim(min(scores), 1.4 * max(scores))
fig.set_figwidth(10)

# %%
score_mean = taxi_data["score"].mean()
score_std = taxi_data["score"].std()
score_cutoff = score_mean + 3 * score_std

anomalies = taxi_data_subset[taxi_data_subset["score"] > score_cutoff]
anomalies
# Out:
#                  timestamp  value     score
# 37     2014-07-01 18:30:00  27598  2.189453
# 38     2014-07-01 19:00:00  26827  1.684940
# 87     2014-07-02 19:30:00  26872  1.699862
# 134    2014-07-03 19:00:00  29985  3.057521
# 527    2014-07-11 23:30:00  26873  1.699686
# ...                    ...    ...       ...
# 10270  2015-01-30 23:00:00  26928  1.730542
# 10309  2015-01-31 18:30:00  27286  1.952488
# 10310  2015-01-31 19:00:00  28804  2.671885
# 10311  2015-01-31 19:30:00  27773  2.245345
# 10317  2015-01-31 22:30:00  27309  1.965798
#
# [195 rows x 3 columns]

# %%
ax2.plot(anomalies.index, anomalies.score, "ko")
fig

# %%
sagemaker.Session().delete_endpoint(rcf_inference.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
import numpy as np


def shingle(data, shingle_size):
    num_data = len(data)
    shingled_data = np.zeros((num_data - shingle_size, shingle_size))

    for n in range(num_data - shingle_size):
        shingled_data[n] = data[n : (n + shingle_size)]
    return shingled_data


# single data with shingle size=48 (one day)
shingle_size = 48
prefix_shingled = "sagemaker/randomcutforest_shingled"
taxi_data_shingled = shingle(taxi_data.values[:, 1], shingle_size)
print(taxi_data_shingled)
# Out:
# [[10844.  8127.  6210. ... 21733. 20104. 16111.]
#  [ 8127.  6210.  4656. ... 20104. 16111. 13370.]
#  [ 6210.  4656.  3820. ... 16111. 13370.  9945.]
#  ...
#  [26874. 26928. 26000. ... 23719. 24670. 25721.]
#  [26928. 26000. 25778. ... 24670. 25721. 27309.]
#  [26000. 25778. 23304. ... 25721. 27309. 26591.]]

# %%
session = sagemaker.Session()

# specify general training job information
rcf = RandomCutForest(
    role=execution_role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    data_location=f"s3://{bucket}/{prefix_shingled}/",
    output_path=f"s3://{bucket}/{prefix_shingled}/output",
    num_samples_per_tree=512,
    num_trees=50,
)

# automatically upload the training data to S3 and run the training job
rcf.fit(rcf.record_set(taxi_data_shingled))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-04-27 01:13:41 Starting - Starting the training job...
# 2022-04-27 01:14:04 Starting - Preparing the instances for trainingProfilerReport-1651022020: InProgress
# .........
# 2022-04-27 01:15:37 Downloading - Downloading input data...
# 2022-04-27 01:16:08 Training - Downloading the training image.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/27/2022 01:16:55 INFO 140255510312768 integration.py:636] worker started
# [04/27/2022 01:16:55 INFO 140255510312768] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [04/27/2022 01:16:55 INFO 140255510312768] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '48', 'mini_batch_size': '1000', 'num_samples_per_tree': '512', 'num_trees': '50'}
# [04/27/2022 01:16:55 INFO 140255510312768] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '50', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '48'}
# [04/27/2022 01:16:55 WARNING 140255510312768] Loggers have already been setup.
# [04/27/2022 01:16:55 INFO 140255510312768] Launching parameter server for role scheduler
# [04/27/2022 01:16:55 INFO 140255510312768] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-80-144.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-01-13-40-871', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-01-13-40-871', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-f0945c771cad8f8b40f899602b7cd52142505aec31d5c3fde3f8301605b00f50-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [04/27/2022 01:16:55 INFO 140255510312768] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-80-144.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-01-13-40-871', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-01-13-40-871', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-f0945c771cad8f8b40f899602b7cd52142505aec31d5c3fde3f8301605b00f50-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.80.144', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [04/27/2022 01:16:55 INFO 140255510312768] Launching parameter server for role server
# [04/27/2022 01:16:55 INFO 140255510312768] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-80-144.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-01-13-40-871', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-01-13-40-871', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-f0945c771cad8f8b40f899602b7cd52142505aec31d5c3fde3f8301605b00f50-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [04/27/2022 01:16:55 INFO 140255510312768] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-80-144.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-01-13-40-871', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-01-13-40-871', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-f0945c771cad8f8b40f899602b7cd52142505aec31d5c3fde3f8301605b00f50-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.80.144', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [04/27/2022 01:16:55 INFO 140255510312768] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-80-144.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-04-27-01-13-40-871', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:195566616656:training-job/randomcutforest-2022-04-27-01-13-40-871', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-f0945c771cad8f8b40f899602b7cd52142505aec31d5c3fde3f8301605b00f50-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.80.144', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 35 is a shell:scheduler.
# Process 44 is a shell:server.
# Process 1 is a worker.
# [04/27/2022 01:16:55 INFO 140255510312768] Using default worker.
# [04/27/2022 01:16:55 INFO 140255510312768] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/27/2022 01:16:55 INFO 140255510312768] Checkpoint loading and saving are disabled.
# [04/27/2022 01:16:55 INFO 140255510312768] Verifying hyperparamemters...
# [04/27/2022 01:16:55 INFO 140255510312768] Hyperparameters are correct.
# [04/27/2022 01:16:55 INFO 140255510312768] Validating that feature_dim agrees with dimensions in training data...
# [04/27/2022 01:16:55 INFO 140255510312768] feature_dim is correct.
# [04/27/2022 01:16:55 INFO 140255510312768] Validating memory limits...
# [04/27/2022 01:16:55 INFO 140255510312768] Available memory in bytes: 15303098368
# [04/27/2022 01:16:55 INFO 140255510312768] Estimated sample size in bytes: 19660800
# [04/27/2022 01:16:55 INFO 140255510312768] Estimated memory needed to build the forest in bytes: 49152000
# [04/27/2022 01:16:55 INFO 140255510312768] Memory limits validated.
# [04/27/2022 01:16:55 INFO 140255510312768] Starting cluster sharing facilities...
# [04/27/2022 01:16:55 INFO 140254064297728] concurrency model: async
# [04/27/2022 01:16:55 INFO 140255510312768] Create Store: dist_async
# [04/27/2022 01:16:55 INFO 140254064297728] masquerade (NAT) address: None
# [04/27/2022 01:16:55 INFO 140254064297728] passive ports: None
# [04/27/2022 01:16:55 INFO 140254064297728] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [04/27/2022 01:16:57 INFO 140255510312768] Cluster sharing facilities started.
# [04/27/2022 01:16:57 INFO 140255510312768] Verifying all workers are accessible...
# [04/27/2022 01:16:57 INFO 140255510312768] All workers accessible.
# [04/27/2022 01:16:57 INFO 140255510312768] Initializing Sampler...
# [04/27/2022 01:16:57 INFO 140255510312768] Sampler correctly initialized.
# #metrics {"StartTime": 1651022215.8109453, "EndTime": 1651022217.3140244, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1496.4914321899414, "count": 1, "min": 1496.4914321899414, "max": 1496.4914321899414}}}
# #metrics {"StartTime": 1651022217.3142653, "EndTime": 1651022217.3143153, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-04-27 01:16:57.314] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1503, "num_examples": 1, "num_bytes": 412000}
# [04/27/2022 01:16:57 INFO 140255510312768] Sampling training data...
# [2022-04-27 01:16:57.344] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 29, "num_examples": 11, "num_bytes": 4232064}
# [04/27/2022 01:16:57 INFO 140255510312768] Sampling training data completed.
# #metrics {"StartTime": 1651022217.314208, "EndTime": 1651022217.3522394, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 37.37306594848633, "count": 1, "min": 37.37306594848633, "max": 37.37306594848633}}}
# [04/27/2022 01:16:57 INFO 140255510312768] Early stop condition met. Stopping training.
# [04/27/2022 01:16:57 INFO 140255510312768] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1651022217.3148298, "EndTime": 1651022217.3527198, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10272.0, "count": 1, "min": 10272, "max": 10272}, "Total Batches Seen": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Max Records Seen Between Resets": {"sum": 10272.0, "count": 1, "min": 10272, "max": 10272}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 10272.0, "count": 1, "min": 10272, "max": 10272}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
# [04/27/2022 01:16:57 INFO 140255510312768] #throughput_metric: host=algo-1, train throughput=269802.1171917564 records/second
# [04/27/2022 01:16:57 INFO 140255510312768] Master node: building Random Cut Forest...
# [04/27/2022 01:16:57 INFO 140255510312768] Gathering samples...
# [04/27/2022 01:16:57 INFO 140255510312768] 10272 samples gathered
# [04/27/2022 01:16:57 INFO 140255510312768] Building Random Cut Forest...
# [04/27/2022 01:16:57 INFO 140255510312768] Random Cut Forest built:
# ForestInfo{num_trees: 50, num_samples_in_forest: 10250, num_samples_per_tree: 205, sample_dim: 48, shingle_size: 1, trees_num_nodes: [409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, 409, ], trees_depth: [27, 18, 18, 21, 17, 18, 19, 19, 17, 20, 23, 17, 17, 17, 20, 19, 20, 19, 15, 18, 19, 19, 20, 16, 16, 16, 21, 19, 18, 20, 17, 18, 18, 21, 16, 20, 17, 16, 19, 16, 20, 17, 24, 21, 19, 21, 19, 20, 17, 22, ], max_num_nodes: 409, min_num_nodes: 409, avg_num_nodes: 409, max_tree_depth: 27, min_tree_depth: 15, avg_tree_depth: 18, mem_size: 17505648}
# #metrics {"StartTime": 1651022217.352361, "EndTime": 1651022217.4121857, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 49.99279975891113, "count": 1, "min": 49.99279975891113, "max": 49.99279975891113}, "model.bytes": {"sum": 17505648.0, "count": 1, "min": 17505648, "max": 17505648}, "finalize.time": {"sum": 58.99691581726074, "count": 1, "min": 58.99691581726074, "max": 58.99691581726074}}}
# [04/27/2022 01:16:57 INFO 140255510312768] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1651022217.4123104, "EndTime": 1651022217.7240121, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 311.63573265075684, "count": 1, "min": 311.63573265075684, "max": 311.63573265075684}}}
# [04/27/2022 01:16:57 INFO 140255510312768] Test data is not provided.
# #metrics {"StartTime": 1651022217.7241247, "EndTime": 1651022217.7242775, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 36.90171241760254, "count": 1, "min": 36.90171241760254, "max": 36.90171241760254}, "totaltime": {"sum": 1961.1189365386963, "count": 1, "min": 1961.1189365386963, "max": 1961.1189365386963}}}
# [04/27/2022 01:16:57 INFO 140255510312768 integration.py:636] worker closed
#
# 2022-04-27 01:17:14 Uploading - Uploading generated training model
# 2022-04-27 01:17:14 Completed - Training job completed
# Training seconds: 97
# Billable seconds: 97

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

rcf_inference = rcf.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")

rcf_inference.serializer = CSVSerializer()
rcf_inference.deserializer = JSONDeserializer()
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ----------!

# %%
print(rcf_inference.content_type, rcf_inference.accept)
# Out:
# text/csv ('application/json',)

# %%
# Score the shingled datapoints
results = rcf_inference.predict(
    taxi_data_shingled, initial_args={"ContentType": "text/csv", "Accept": "application/json"}
)
scores = np.array([datum["score"] for datum in results["scores"]])

# compute the shingled score distribution and cutoff and determine anomalous scores
score_mean = scores.mean()
score_std = scores.std()
score_cutoff = score_mean + 3 * score_std

anomalies = scores[scores > score_cutoff]
anomaly_indices = np.arange(len(scores))[scores > score_cutoff]

print(anomalies)
# Out:
# [1.453398   1.43689669 1.44808651 1.49337067 1.51074849 1.53591785
#  1.58859876 1.57360929 1.62437046 1.68915794 1.64985237 1.61975329
#  1.70823125 1.70126821 1.73821864 1.76174797 1.73657851 1.73192876
#  1.74842612 1.63505033 1.53936191 1.50569449 1.69157432 1.72746996
#  1.64493031 1.60533811 1.57898719 1.60172368 1.5728291  1.55395486
#  1.58140601 1.54972197 1.46222543 1.55674557 1.55629524 1.46952436
#  1.44437019 1.44975338 1.46131533 1.4692033  1.45137299 1.48299176
#  1.50053282 1.47401968 1.50654217 1.54538164 1.58932289 1.50152779
#  1.46681776 1.4965702  1.51784744 1.565696   1.56534343 1.57302139
#  1.56759735 1.58305438 1.54537367 1.59187514 1.54608717 1.58974607
#  1.55893039 1.50560981 1.4785793  1.48365269 1.48501053 1.47741296
#  1.45347863 1.45884155 1.4905194  1.48056505 1.46951778 1.46850259
#  1.4629729  1.50342666 1.48623193 1.56734494 1.43638209 1.46766317
#  1.4614818  1.47031478 1.53737779 1.57684287 1.58405364 1.59879515
#  1.64248809 1.67375108 1.63579957 1.74549698 1.76994457 1.78567373
#  1.79276885 1.79942576 1.81362692 1.84663156 1.90559034 1.93457872
#  1.97943367 2.01324733 2.04787499 2.08474317 2.10398603 2.1151169
#  2.13378602 2.16668033 2.19842881 2.20378646 2.22926648 2.25389285
#  2.27053964 2.27674765 2.25584106 2.26267259 2.27111246 2.2692069
#  2.27853529 2.32817572 2.28591786 2.27086868 2.26462883 2.25850082
#  2.25043929 2.24611028 2.20744615 2.20210456 2.12051935 2.11049175
#  2.09470774 2.09692595 2.07967044 2.07172344 2.04067229 2.0048575
#  2.02853113 2.00617787 1.92979376 1.91208354 1.84631112 1.87970886
#  1.9000722  1.86574037 1.78503311 1.80896223 1.83011487 1.7482774
#  1.703045   1.71301171 1.72989812 1.69224088 1.62511322 1.57569505
#  1.59868816 1.58332675 1.5675371  1.5013257  1.4707412  1.49823073]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

#
# *Try this out* - change `start` and `end` to zoom in on the
# anomaly found earlier in this notebook
#
start, end = 0, len(taxi_data)
taxi_data_subset = taxi_data[start:end]

ax1.plot(taxi_data["value"], color="C0", alpha=0.8)
ax2.plot(scores, color="C1")
ax2.scatter(anomaly_indices, anomalies, color="k")

ax1.grid(which="major", axis="both")
ax1.set_ylabel("Taxi Ridership", color="C0")
ax2.set_ylabel("Anomaly Score", color="C1")
ax1.tick_params("y", colors="C0")
ax2.tick_params("y", colors="C1")
ax1.set_ylim(0, 40000)
ax2.set_ylim(min(scores), 1.4 * max(scores))
fig.set_figwidth(10)

# %%
sagemaker.Session().delete_endpoint(rcf_inference.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
